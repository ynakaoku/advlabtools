# %% [markdown]
# # iperf3によるVM間の転送性能テスト

# %% [markdown]
# ### 同一のNSX論理スイッチに接続する4つのVM間でTCPスループットを計測(60秒)

# %%
# %run -i iperf3_peer.py -C DLS4-config -N DLS4 -t 60
# Out:
# /root/mytesttools/tester/jupyter/reports/DLS4-iperf3-180315-214411/DLS4-cl-172.16.130.203.json
# /root/mytesttools/tester/jupyter/reports/DLS4-iperf3-180315-214411/DLS4-cl-172.16.130.204.json
# /root/mytesttools/tester/jupyter/reports/DLS4-iperf3-180315-214411/DLS4-cl-172.16.130.201.json
# /root/mytesttools/tester/jupyter/reports/DLS4-iperf3-180315-214411/DLS4-cl-172.16.130.202.json

# %% [markdown]
# ### NSX ESGを介した4つのVM間でTCPスループットを計測(60秒)

# %%
# %run -i iperf3_peer.py -C ESG4-config -N ESG4 -t 60
# Out:
# /root/mytesttools/tester/jupyter/reports/ESG4-iperf3-180315-214601/ESG4-cl-172.16.130.203.json
# /root/mytesttools/tester/jupyter/reports/ESG4-iperf3-180315-214601/ESG4-cl-172.16.130.204.json
# /root/mytesttools/tester/jupyter/reports/ESG4-iperf3-180315-214601/ESG4-cl-172.16.130.201.json
# /root/mytesttools/tester/jupyter/reports/ESG4-iperf3-180315-214601/ESG4-cl-172.16.130.202.json
