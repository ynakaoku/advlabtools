# %% [markdown]
# # iperf3によるVM間の転送性能テスト
#
# ## Kubernets POD 編

# %% [markdown]
# ### テスト用K8s nodeの稼働状態を確認

# %%
# !kubectl get nodes -o wide --show-labels
# Out:
# NAME       STATUS    AGE       EXTERNAL-IP   LABELS
# minikube   Ready     6h        <none>        beta.kubernetes.io/arch=amd64,beta.kubernetes.io/os=linux,id=node1,kubernetes.io/hostname=minikube

# %% [markdown]
# ### テスト用PODの実行状態を確認

# %%
# !kubectl get pods -o wide -l app=iperf3
# Out:
# NAME                           READY     STATUS    RESTARTS   AGE       IP            NODE
# iperf3-dep1-57d958f989-ddtsw   1/1       Running   0          4m        172.17.0.4    minikube
# iperf3-dep2-7998c4ff88-m9jkx   1/1       Running   0          4m        172.17.0.5    minikube
# iperf3-dep3-6cd575b98c-pmrtk   1/1       Running   0          4m        172.17.0.6    minikube
# iperf3-dep4-65d84b5d78-v4qfl   1/1       Running   0          4m        172.17.0.7    minikube
# iperf3-dep5-798d9b5c7-k6ksd    1/1       Running   0          4m        172.17.0.8    minikube
# iperf3-dep6-65766f4ff-cjjrh    1/1       Running   0          4m        172.17.0.9    minikube
# iperf3-dep7-5f6b996c6c-ss9w4   1/1       Running   0          4m        172.17.0.10   minikube
# iperf3-dep8-6f7b7d75d6-mw22j   1/1       Running   0          4m        172.17.0.11   minikube

# %% [markdown]
# ### テストスクリプトのオプション

# %%
# %run -i k8s_iperf3_peer.py -h
# Out:
# usage: k8s_iperf3_peer.py [-h] -C CONFIGFILE -N TESTNAME [-i INTERVAL]
#                           [-b BANDWIDTH] [-M MSS] [-P PARALLEL] [-t TIME] [-u]
#                           [--getserveroutput] [--getesxtop]
#
# Standard Arguments for iperf3 testing
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -C CONFIGFILE, --configfile CONFIGFILE
#                         config file for iperf3 test
#   -N TESTNAME, --testname TESTNAME
#                         name for the iperf3 test, not to be unique
#   -i INTERVAL, --interval INTERVAL
#                         second for periodic bandwidth report, defaulty no
#                         report
#   -b BANDWIDTH, --bandwidth BANDWIDTH
#                         target bandwidth in bps, default 1 Mbit/sec for UDP,
#                         unlimited for TCP
#   -M MSS, --mss MSS     TCP maximum segmnet size (MTU - 40), default 1460
#                         bytes
#   -P PARALLEL, --parallel PARALLEL
#                         number of parallel client streams to run, default 1
#                         stream
#   -t TIME, --time TIME  time in seconds to transmit for, default 10 secs
#   -u, --udp             use UDP rather than TCP
#   --getserveroutput     get iperf3 test results from servers
#   --getesxtop           get esxtop measurement results from hosts

# %% [markdown]
# ### 同一の k8s namespace 内の4つのVM間でUDPスループットを計測(60秒)

# %%
# %run -i k8s_iperf3_peer.py -C k8s-4peers-config.yaml -N k8s-4peers -t 60 -b 1G -u
# Out:
# [Test parameters per Peers]
# | Protocol: UDP | Bandwidth(bps): 1G | MSS(byte): 1460 | Streams: 1 | Interval(s): 1 | Time(s): 60 | Use Client side data
# Testing, wait 60 seconds...  done
# [Test Result]
# | Number of peers: 4
# [Test Result]
# | Number of hosts: 0
#
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-155035/k8s-4peers-cl-iperf3-dep8-6f7b7d75d6-mw22j.json
# | Avg Bandwidth(Gbps): 0.998722 | Jitter(ms): 0.0972582 | Lost Packets: 594647 | Lost %: 65.0352
# | Sender CPU%: 30.961 | Receiver CPU%: 3.91578
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-155035/k8s-4peers-cl-iperf3-dep5-798d9b5c7-k6ksd.json
# | Avg Bandwidth(Gbps): 0.998763 | Jitter(ms): 0.100024 | Lost Packets: 606492 | Lost %: 66.3323
# | Sender CPU%: 31.0196 | Receiver CPU%: 3.71371
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-155035/k8s-4peers-cl-iperf3-dep6-65766f4ff-cjjrh.json
# | Avg Bandwidth(Gbps): 0.998389 | Jitter(ms): 0.0955793 | Lost Packets: 603515 | Lost %: 66.027
# | Sender CPU%: 31.0088 | Receiver CPU%: 3.97099
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-155035/k8s-4peers-cl-iperf3-dep7-5f6b996c6c-ss9w4.json
# | Avg Bandwidth(Gbps): 0.99865 | Jitter(ms): 0.0374078 | Lost Packets: 585875 | Lost %: 64.0794
# | Sender CPU%: 31.1251 | Receiver CPU%: 4.11497

# %% [markdown]
# ### 同一の k8s namespace 内の4つのVM間でTCPスループットを計測(60秒)

# %%
# %run -i k8s_iperf3_peer.py -C k8s-4peers-config.yaml -N k8s-4peers -t 60 -b 1G
# Out:
# [Test parameters per Peers]
# | Protocol: TCP | Bandwidth(bps): 1G | MSS(byte): 1460 | Streams: 1 | Interval(s): 1 | Time(s): 60 | Use Client side data
# Testing, wait 60 seconds...  done
# [Test Result]
# | Number of peers: 4
# [Test Result]
# | Number of hosts: 0
#
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-092937/k8s-4peers-cl-iperf3-dep6-65766f4ff-nkhcd.json
# | Avg Bandwidth(Gbps): 0.998417 | Retransmits: 5
# | Sender CPU%: 4.89568 | Receiver CPU%: 3.74639
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-092937/k8s-4peers-cl-iperf3-dep8-556b569d5f-tsx29.json
# | Avg Bandwidth(Gbps): 0.998432 | Retransmits: 10
# | Sender CPU%: 4.01909 | Receiver CPU%: 3.03924
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-092937/k8s-4peers-cl-iperf3-dep7-5f6b996c6c-24lzf.json
# | Avg Bandwidth(Gbps): 0.998409 | Retransmits: 5
# | Sender CPU%: 4.89292 | Receiver CPU%: 3.80726
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190130-092937/k8s-4peers-cl-iperf3-dep5-76f8996779-r4g6f.json
# | Avg Bandwidth(Gbps): 0.998427 | Retransmits: 2293
# | Sender CPU%: 4.01262 | Receiver CPU%: 3.2328

# %%
# %run -i k8s_iperf3_peer.py -C k8s-4peers-config.yaml -N k8s-4peers -t 60
# Out:
# [Test parameters per Peers]
# | Protocol: TCP | Unlimitted Bandwidth | MSS(byte): 1460 | Streams: 1 | Interval(s): 1 | Time(s): 60 | Use Client side data
# Testing, wait 60 seconds...  done
# [Test Result]
# | Number of peers: 4
# [Test Result]
# | Number of hosts: 0
#
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190129-175840/k8s-4peers-cl-iperf3-dep7-5f6b996c6c-djsb6.json
# | Avg Bandwidth(Gbps): 6.92168 | Retransmits: 461
# | Sender CPU%: 24.7653 | Receiver CPU%: 18.7672
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190129-175840/k8s-4peers-cl-iperf3-dep5-76f8996779-48wfc.json
# | Avg Bandwidth(Gbps): 6.82746 | Retransmits: 32
# | Sender CPU%: 25.6081 | Receiver CPU%: 18.2827
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190129-175840/k8s-4peers-cl-iperf3-dep8-556b569d5f-ls82m.json
# | Avg Bandwidth(Gbps): 7.21151 | Retransmits: 6100
# | Sender CPU%: 25.5151 | Receiver CPU%: 19.9133
# /Users/ynakaoku/minikube-apps/advlabtools/tester/jupyter/reports/k8s-4peers-iperf3-190129-175840/k8s-4peers-cl-iperf3-dep6-65766f4ff-x82hf.json
# | Avg Bandwidth(Gbps): 6.66535 | Retransmits: 79
# | Sender CPU%: 24.8109 | Receiver CPU%: 17.9526

# %% [markdown]
# ### テスト用Pythonスクリプトを直接編集してテストをカスタマイズ

# %%
#! /usr/bin/env python
# -*- coding: utf-8 -*-

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import os
import subprocess
import json
import glob

class FixedOrderFormatter(ticker.ScalarFormatter):
    def __init__(self, order_of_mag=0, useOffset=True, useMathText=True):
        self._order_of_mag = order_of_mag
        ticker.ScalarFormatter.__init__(self, useOffset=useOffset,
                                 useMathText=useMathText)
    def _set_orderOfMagnitude(self, range):
        self.orderOfMagnitude = self._order_of_mag

ConfigFile='DLS4-config'
TestName='mytest01'
Interval='1'
Bandwidth='1G'
Time='10'
Udp=False

def set_option():
    options = " -C " + ConfigFile + " -N " + TestName + " -J -s "
    if Interval:
        options = options + " -i " + Interval
    if Bandwidth:
        options = options + " -b " + Bandwidth
    if Time:
        options = options + " -t " + Time
    if Udp:
        options = options + " -u "

    return options

def init_plt():
    plt.figure(num=None, figsize=(20, 6), dpi=60, facecolor='w', edgecolor='k')
    plt.rcParams["font.size"] = 15
    plt.rcParams["xtick.labelsize"] = 12
    plt.rcParams["ytick.labelsize"] = 12
    plt.rcParams["legend.fontsize"] = 12
    plt.grid()
    plt.axhline(y=0)
    plt.xlabel("Interval(s)")
    plt.ylabel(u"Throughput(Gbps)")
    plt.gca().yaxis.set_major_formatter(FixedOrderFormatter(9, useOffset=False))
    plt.gca().get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))

def main():
    cmd = "../scripts/run_iperf3_peer.bash "
    cmd_options = set_option()

    print 'Testing, wait {} seconds... '.format(Time),
    dirname = str(subprocess.check_output( cmd+cmd_options, shell=True, universal_newlines=True )).replace('\n','')
    print 'done'

    json_files = glob.glob(dirname + "/*cl*.json")

    for file in json_files:
        print(file)
        f = open(file, 'r')
        perf_dict = json.load(f)

        init_plt()

        x = np.array(range(len(perf_dict["intervals"])))
        y = np.array([])

        for p in perf_dict["intervals"]:
            y = np.append(y, p["sum"]["bits_per_second"])

        plt.plot(x, y, "r",marker="o",markersize=2)

        plt.show()

# Start program
if __name__ == "__main__":
    main()
# Out:
# Testing, wait 10 seconds...  done
# /root/mytesttools/tester/jupyter/reports/mytest01-iperf3-180328-194704/mytest01-cl-172.16.130.202.json
# /root/mytesttools/tester/jupyter/reports/mytest01-iperf3-180328-194704/mytest01-cl-172.16.130.201.json
# /root/mytesttools/tester/jupyter/reports/mytest01-iperf3-180328-194704/mytest01-cl-172.16.130.204.json
# /root/mytesttools/tester/jupyter/reports/mytest01-iperf3-180328-194704/mytest01-cl-172.16.130.203.json
